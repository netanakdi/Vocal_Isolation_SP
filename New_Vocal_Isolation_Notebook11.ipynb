# %%
# !pip install demucs torchaudio librosa numpy scipy matplotlib soundfile tqdm
# Out:
# Requirement already satisfied: demucs in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (4.0.1)
# Requirement already satisfied: torchaudio in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (2.6.0)
# Requirement already satisfied: librosa in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (0.10.2.post1)
# Requirement already satisfied: numpy in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (2.1.3)
# Requirement already satisfied: scipy in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (1.15.2)
# Requirement already satisfied: matplotlib in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (3.10.0)
# Requirement already satisfied: soundfile in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (0.13.1)
# Requirement already satisfied: tqdm in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (4.67.1)
# Requirement already satisfied: dora-search in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from demucs) (0.1.12)
# Requirement already satisfied: einops in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from demucs) (0.8.1)
# Requirement already satisfied: julius>=0.2.3 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from demucs) (0.2.7)
# Requirement already satisfied: lameenc>=1.2 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from demucs) (1.8.1)
# Requirement already satisfied: openunmix in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from demucs) (1.3.0)
# Requirement already satisfied: pyyaml in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from demucs) (6.0.2)
# Requirement already satisfied: torch>=1.8.1 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from demucs) (2.6.0)
# Requirement already satisfied: filelock in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from torch>=1.8.1->demucs) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from torch>=1.8.1->demucs) (4.12.2)
# Requirement already satisfied: networkx in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from torch>=1.8.1->demucs) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from torch>=1.8.1->demucs) (3.1.5)
# Requirement already satisfied: fsspec in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from torch>=1.8.1->demucs) (2025.2.0)
# Requirement already satisfied: setuptools in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from torch>=1.8.1->demucs) (75.8.1)
# Requirement already satisfied: sympy==1.13.1 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from torch>=1.8.1->demucs) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.8.1->demucs) (1.3.0)
# Requirement already satisfied: audioread>=2.1.9 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from librosa) (5.2.1)
# Requirement already satisfied: numba>=0.51.0 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from librosa) (0.61.0)
# Requirement already satisfied: pooch>=1.1 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: lazy-loader>=0.1 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from librosa) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: cffi>=1.0 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from soundfile) (1.17.1)
# Requirement already satisfied: pycparser in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from cffi>=1.0->soundfile) (2.22)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from numba>=0.51.0->librosa) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from pooch>=1.1->librosa) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: six>=1.5 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: omegaconf in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from dora-search->demucs) (2.3.0)
# Requirement already satisfied: retrying in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from dora-search->demucs) (1.3.4)
# Requirement already satisfied: submitit in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from dora-search->demucs) (1.5.2)
# Requirement already satisfied: treetable in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from dora-search->demucs) (0.2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from jinja2->torch>=1.8.1->demucs) (3.0.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from omegaconf->dora-search->demucs) (4.9.3)
# Requirement already satisfied: cloudpickle>=1.2.1 in /Users/roydruker/.venvs/py3118/lib/python3.12/site-packages (from submitit->dora-search->demucs) (3.1.1)

# %%
import os
os.environ["TORCH_COMPILE_DISABLE"] = "1"

# %%
import glob
import numpy as np
import librosa
import librosa.display
import torch
import torchaudio
import soundfile as sf
import matplotlib.pyplot as plt
import pandas as pd

from tqdm import tqdm
from mir_eval.separation import bss_eval_sources
from torch.utils.data import Dataset, DataLoader
from scipy.signal import butter, lfilter
from scipy.io.wavfile import write as wav_write

from demucs.apply import apply_model
from demucs import pretrained
import torch.nn as nn
import torch.optim as optim

# %%
# Load pre-trained Demucs model
model = pretrained.get_model("mdx_extra")
print(model)

# Freeze encoder layers for all models inside BagOfModels
for sub_model in model.models:
    for param in sub_model.encoder.parameters():
        param.requires_grad = False  # Keep pretrained weights

# Fine-tune decoder layers
for sub_model in model.models:
    for param in sub_model.decoder.parameters():
        param.requires_grad = True  # Allow training

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

print(f"Model loaded and fine-tuning enabled on {device}")
# Out:
# BagOfModels(
#   (models): ModuleList(
#     (0): HDemucs(
#       (encoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv2d(4, 48, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv2d(48, 96, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv2d(96, 192, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv2d(192, 384, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv2d(384, 768, kernel_size=(8, 1), stride=(4, 1))
#           (norm1): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#         (5): HEncLayer(
#           (conv): Conv1d(768, 1536, kernel_size=(4,), stride=(2,), padding=(1,))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(1,), stride=(1,))
#           (norm2): GroupNorm(4, 3072, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#       )
#       (decoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(1536, 768, kernel_size=(4,), stride=(2,))
#           (norm2): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): GroupNorm(4, 3072, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose2d(768, 384, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose2d(384, 192, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose2d(192, 96, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose2d(96, 48, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (5): HDecLayer(
#           (conv_tr): ConvTranspose2d(48, 16, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#       )
#       (tencoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv1d(2, 48, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv1d(48, 96, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv1d(96, 192, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv1d(192, 384, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv1d(384, 768, kernel_size=(8,), stride=(4,), padding=(2,))
#         )
#       )
#       (tdecoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(768, 384, kernel_size=(8,), stride=(4,))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose1d(384, 192, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose1d(192, 96, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose1d(96, 48, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose1d(48, 8, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#       )
#       (freq_emb): ScaledEmbedding(
#         (embedding): Embedding(512, 48)
#       )
#     )
#     (1-2): 2 x HDemucs(
#       (encoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv2d(2, 48, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv2d(48, 96, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv2d(96, 192, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv2d(192, 384, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv2d(384, 768, kernel_size=(8, 1), stride=(4, 1))
#           (norm1): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#         (5): HEncLayer(
#           (conv): Conv1d(768, 1536, kernel_size=(4,), stride=(2,), padding=(1,))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(1,), stride=(1,))
#           (norm2): GroupNorm(4, 3072, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#       )
#       (decoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(1536, 768, kernel_size=(4,), stride=(2,))
#           (norm2): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): GroupNorm(4, 3072, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose2d(768, 384, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose2d(384, 192, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose2d(192, 96, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose2d(96, 48, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (5): HDecLayer(
#           (conv_tr): ConvTranspose2d(48, 8, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#       )
#       (tencoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv1d(2, 48, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv1d(48, 96, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv1d(96, 192, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv1d(192, 384, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv1d(384, 768, kernel_size=(8,), stride=(4,), padding=(2,))
#         )
#       )
#       (tdecoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(768, 384, kernel_size=(8,), stride=(4,))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose1d(384, 192, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose1d(192, 96, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose1d(96, 48, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose1d(48, 8, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#       )
#       (freq_emb): ScaledEmbedding(
#         (embedding): Embedding(512, 48)
#       )
#     )
#     (3): HDemucs(
#       (encoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv2d(4, 48, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv2d(48, 96, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv2d(96, 192, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv2d(192, 384, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv2d(384, 768, kernel_size=(8, 1), stride=(4, 1))
#           (norm1): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#         (5): HEncLayer(
#           (conv): Conv1d(768, 1536, kernel_size=(4,), stride=(2,), padding=(1,))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(1,), stride=(1,))
#           (norm2): GroupNorm(4, 3072, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#       )
#       (decoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(1536, 768, kernel_size=(4,), stride=(2,))
#           (norm2): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): GroupNorm(4, 3072, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose2d(768, 384, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose2d(384, 192, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose2d(192, 96, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose2d(96, 48, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (5): HDecLayer(
#           (conv_tr): ConvTranspose2d(48, 16, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#       )
#       (tencoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv1d(2, 48, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv1d(48, 96, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv1d(96, 192, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv1d(192, 384, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv1d(384, 768, kernel_size=(8,), stride=(4,), padding=(2,))
#         )
#       )
#       (tdecoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(768, 384, kernel_size=(8,), stride=(4,))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose1d(384, 192, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose1d(192, 96, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose1d(96, 48, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose1d(48, 8, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#       )
#       (freq_emb): ScaledEmbedding(
#         (embedding): Embedding(512, 48)
#       )
#     )
#   )
# )
# Model loaded and fine-tuning enabled on cpu

# %%
tracks = pd.read_csv("fma_metadata/tracks.csv", index_col=0, header=[0, 1])
print("Columns in tracks.csv:", tracks.columns)

if ("track", "genre_top") in tracks.columns:
    # Select tracks with vocals
    relevant_genres = ["Pop", "Hip-Hop", "Jazz", "Blues"]
    vocal_tracks = tracks[tracks[("track", "genre_top")].isin(relevant_genres)]

    # Convert track IDs to string
    vocal_track_ids = set(vocal_tracks.index.astype(str))

    print(f"Found {len(vocal_track_ids)} vocal tracks matching genres {relevant_genres}")
else:
    raise ValueError("Genre column ('track', 'genre_top') not found in tracks.csv!")

print("Total vocal tracks selected:", len(vocal_track_ids))
# Out:
# Columns in tracks.csv: MultiIndex([( 'album',          'comments'),
#             ( 'album',      'date_created'),
#             ( 'album',     'date_released'),
#             ( 'album',          'engineer'),
#             ( 'album',         'favorites'),
#             ( 'album',                'id'),
#             ( 'album',       'information'),
#             ( 'album',           'listens'),
#             ( 'album',          'producer'),
#             ( 'album',              'tags'),
#             ( 'album',             'title'),
#             ( 'album',            'tracks'),
#             ( 'album',              'type'),
#             ('artist', 'active_year_begin'),
#             ('artist',   'active_year_end'),
#             ('artist', 'associated_labels'),
#             ('artist',               'bio'),
#             ('artist',          'comments'),
#             ('artist',      'date_created'),
#             ('artist',         'favorites'),
#             ('artist',                'id'),
#             ('artist',          'latitude'),
#             ('artist',          'location'),
#             ('artist',         'longitude'),
#             ('artist',           'members'),
#             ('artist',              'name'),
#             ('artist',  'related_projects'),
#             ('artist',              'tags'),
#             ('artist',           'website'),
#             ('artist',    'wikipedia_page'),
#             (   'set',             'split'),
#             (   'set',            'subset'),
#             ( 'track',          'bit_rate'),
#             ( 'track',          'comments'),
#             ( 'track',          'composer'),
#             ( 'track',      'date_created'),
#             ( 'track',     'date_recorded'),
#             ( 'track',          'duration'),
#             ( 'track',         'favorites'),
#             ( 'track',         'genre_top'),
#             ( 'track',            'genres'),
#             ( 'track',        'genres_all'),
#             ( 'track',       'information'),
#             ( 'track',          'interest'),
#             ( 'track',     'language_code'),
#             ( 'track',           'license'),
#             ( 'track',           'listens'),
#             ( 'track',          'lyricist'),
#             ( 'track',            'number'),
#             ( 'track',         'publisher'),
#             ( 'track',              'tags'),
#             ( 'track',             'title')],
#            )
# Found 6565 vocal tracks matching genres ['Pop', 'Hip-Hop', 'Jazz', 'Blues']
# Total vocal tracks selected: 6565

# %%
FMA_FOLDER = "fma_small"
AUDIO_SAMPLE_RATE = 44100  # Modify if needed
NUM_FILES = 10  # Limit processing to avoid space issues
OUTPUT_FOLDER = "separated_files"

# %%
# Get paths of MP3 files corresponding to vocal tracks
AUDIO_FILES = glob.glob(os.path.join(FMA_FOLDER, "*/*.mp3"))
file_names = [os.path.basename(f).split(".")[0] for f in AUDIO_FILES]

selected_files = [f for f in AUDIO_FILES if os.path.basename(f).split(".")[0] in vocal_track_ids]
selected_files = np.random.choice(selected_files, min(NUM_FILES, len(selected_files)), replace=False)

print(f"Found {len(AUDIO_FILES)} total MP3 files.")
print(f"Selected {len(selected_files)} vocal files for processing.")
# Out:
# Found 8000 total MP3 files.
# Selected 10 vocal files for processing.

# %%
os.makedirs("fma_wav", exist_ok=True)

for file in tqdm(selected_files, desc="Converting MP3 to WAV"):
    y, sr = librosa.load(file, sr=AUDIO_SAMPLE_RATE, mono=False)
    file_name = os.path.basename(file).replace(".mp3", ".wav")

    # Normalize audio
    y = y / np.max(np.abs(y))  # Scale to [-1, 1]
    
    # Save using soundfile to avoid format issues
    sf.write(f"fma_wav/{file_name}", y.T, sr, format='WAV', subtype='PCM_16')

print("MP3 files converted to WAV format")
# Out:
# Converting MP3 to WAV: 100%|██████████| 10/10 [00:03<00:00,  2.85it/s]
# MP3 files converted to WAV format

# %%
def process_audio(file_path, input_model=None):
    """Loads an MP3 file, applies Demucs for vocal separation, and returns separated sources."""
    print(f"Processing {file_path}")

    # Load audio
    y, sr = librosa.load(file_path, sr=AUDIO_SAMPLE_RATE, mono=False)
    if y is None:
        print(f"Skipping {file_path} due to loading error.")
        return None, None, None  # Ensure 3 values are always returned

    print(f"Loaded Audio: Shape = {y.shape}, Sample Rate = {sr}")

    # Convert to tensor for model processing
    y_tensor = torch.tensor(y).unsqueeze(0).to(device)

    with torch.no_grad():
        if input_model:
            sources = apply_model(input_model, y_tensor)  # Use model if provided
        else:
            sources = apply_model(model, y_tensor)  # Default to pre-trained model

    sources = sources.cpu().numpy()
    print(f" Model Output Shape: {sources.shape}")

    # Extract vocals and instrumental
    vocals = sources[0, 0]
    instrumental = sources[0, 1] + sources[0, 2] + sources[0, 3]  # Sum non-vocal components

    return y, vocals, instrumental  # Always return 3 values

# %%
os.makedirs("separated_files", exist_ok=True)

for file in tqdm(selected_files, desc="Processing & Saving"):
    original, vocals, instrumental = process_audio(file, input_model=None)

    if original is None or vocals is None or instrumental is None:
        print(f"Skipping {file} due to missing values.")
        continue

    file_name = os.path.basename(file).replace(".mp3", "")

    vocals = np.asarray(vocals, dtype=np.float32).T  
    instrumental = np.asarray(instrumental, dtype=np.float32).T  

    sf.write(f"separated_files/{file_name}_vocals.wav", vocals, samplerate=AUDIO_SAMPLE_RATE)
    sf.write(f"separated_files/{file_name}_instrumental.wav", instrumental, samplerate=AUDIO_SAMPLE_RATE)

    print(f"Saved: separated_files/{file_name}_vocals.wav, separated_files/{file_name}_instrumental.wav")
# Out:
# Processing & Saving:   0%|          | 0/10 [00:00<?, ?it/s]
# Processing fma_small/150/150017.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
# Processing & Saving:  10%|█         | 1/10 [00:26<03:57, 26.41s/it]
#  Model Output Shape: (1, 4, 2, 1323119)
# Saved: separated_files/150017_vocals.wav, separated_files/150017_instrumental.wav
# Processing fma_small/145/145750.mp3
# Loaded Audio: Shape = (2, 1321967), Sample Rate = 44100
# Processing & Saving:  20%|██        | 2/10 [00:53<03:32, 26.53s/it]
#  Model Output Shape: (1, 4, 2, 1321967)
# Saved: separated_files/145750_vocals.wav, separated_files/145750_instrumental.wav
# Processing fma_small/153/153956.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
# Processing & Saving:  30%|███       | 3/10 [01:19<03:06, 26.63s/it]
#  Model Output Shape: (1, 4, 2, 1323119)
# Saved: separated_files/153956_vocals.wav, separated_files/153956_instrumental.wav
# Processing fma_small/146/146148.mp3
# Loaded Audio: Shape = (2, 1321967), Sample Rate = 44100
# Processing & Saving:  40%|████      | 4/10 [01:44<02:35, 25.97s/it]
#  Model Output Shape: (1, 4, 2, 1321967)
# Saved: separated_files/146148_vocals.wav, separated_files/146148_instrumental.wav
# Processing fma_small/148/148519.mp3
# Loaded Audio: Shape = (2, 1321967), Sample Rate = 44100
# Processing & Saving:  50%|█████     | 5/10 [02:10<02:08, 25.74s/it]
#  Model Output Shape: (1, 4, 2, 1321967)
# Saved: separated_files/148519_vocals.wav, separated_files/148519_instrumental.wav
# Processing fma_small/127/127287.mp3
# Loaded Audio: Shape = (2, 1321967), Sample Rate = 44100
# Processing & Saving:  60%|██████    | 6/10 [02:35<01:42, 25.54s/it]
#  Model Output Shape: (1, 4, 2, 1321967)
# Saved: separated_files/127287_vocals.wav, separated_files/127287_instrumental.wav
# Processing fma_small/121/121317.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
# Processing & Saving:  70%|███████   | 7/10 [02:59<01:15, 25.21s/it]
#  Model Output Shape: (1, 4, 2, 1323119)
# Saved: separated_files/121317_vocals.wav, separated_files/121317_instrumental.wav
# Processing fma_small/142/142093.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
# Processing & Saving:  80%|████████  | 8/10 [03:25<00:50, 25.28s/it]
#  Model Output Shape: (1, 4, 2, 1323119)
# Saved: separated_files/142093_vocals.wav, separated_files/142093_instrumental.wav
# Processing fma_small/121/121313.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
# Processing & Saving:  90%|█████████ | 9/10 [03:51<00:25, 25.45s/it]
#  Model Output Shape: (1, 4, 2, 1323119)
# Saved: separated_files/121313_vocals.wav, separated_files/121313_instrumental.wav
# Processing fma_small/108/108492.mp3
# Loaded Audio: Shape = (2, 1322514), Sample Rate = 44100
# Processing & Saving: 100%|██████████| 10/10 [04:16<00:00, 25.65s/it]
#  Model Output Shape: (1, 4, 2, 1322514)
# Saved: separated_files/108492_vocals.wav, separated_files/108492_instrumental.wav

# %%
class FMA_Dataset(Dataset):
    """Dataset for fine-tuning Demucs using FMA."""
    def __init__(self, data_path, sample_rate=44100, fixed_length=5.0):
        """
        Args:
            data_path: Path to dataset directory
            sample_rate: Audio sample rate (default 44100 Hz)
            fixed_length: Fixed length in seconds (default 5s)
        """
        self.data_path = data_path
        self.sample_rate = sample_rate
        self.fixed_samples = int(fixed_length * sample_rate)  # Convert seconds to samples
        self.files = [f for f in os.listdir(data_path) if f.endswith("_vocals.wav")]

    def __len__(self):
        return len(self.files)

    def load_audio(self, path):
        """Load an audio file and ensure it has the correct length."""
        audio, sr = torchaudio.load(path)

        # Ensure correct sample rate
        if sr != self.sample_rate:
            audio = torchaudio.transforms.Resample(sr, self.sample_rate)(audio)

        # If too short, pad with zeros
        if audio.shape[1] < self.fixed_samples:
            pad_size = self.fixed_samples - audio.shape[1]
            audio = torch.nn.functional.pad(audio, (0, pad_size))

        # If too long, trim to fixed length
        elif audio.shape[1] > self.fixed_samples:
            audio = audio[:, :self.fixed_samples]

        return audio

    def __getitem__(self, idx):
        vocal_path = os.path.join(self.data_path, self.files[idx])
        instrumental_path = vocal_path.replace("_vocals.wav", "_instrumental.wav")

        vocals = self.load_audio(vocal_path)
        instrumental = self.load_audio(instrumental_path)

        mix = vocals + instrumental  # Create the mix dynamically

        return mix, vocals  # Mix as input, vocals as target

# ✅ Reload dataset with fixed-length samples
train_dataset = FMA_Dataset("separated_files")
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)

print(f"Training data loaded: {len(train_dataset)} samples")
# Out:
# Training data loaded: 10 samples

# %%
import torch
import librosa
import soundfile as sf
import numpy as np
import os

# Create a directory for saved models and separated files
os.makedirs("checkpoints", exist_ok=True)
os.makedirs("separated_files", exist_ok=True)

# Regular fine-tuning
criterion = nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5, betas=(0.9, 0.999))

num_epochs = 10  
training_losses_per_epoch = []

test_audio_path = "fma_small/135/135054.mp3"  # Test audio to evaluate each epoch

for epoch in range(num_epochs):
    model.train()
    total_loss = 0

    for mix, vocals in train_loader:
        mix, vocals = mix.to(device), vocals.to(device)

        optimizer.zero_grad()
        predictions = apply_model(model, mix)[:, 0, :, :].requires_grad_(True)  
        loss = criterion(predictions, vocals)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    # Compute average loss for the epoch
    avg_loss = total_loss / len(train_loader)
    training_losses_per_epoch.append(avg_loss)
    print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {avg_loss:.6f}")

    # Save model checkpoint
    checkpoint_path = f"/Users/roydruker/Desktop/Neta/Epochs/model_epoch_{epoch+1}.pth"
    torch.save(model.state_dict(), checkpoint_path)
    print(f"Model saved: {checkpoint_path}")

    # Run inference & save separated files
    model.eval()  # Set to evaluation mode
    original_audio, predicted_vocals, predicted_instr = process_audio(test_audio_path, model)

    if original_audio is None or predicted_vocals is None or predicted_instr is None:
        print(f"Skipping {test_audio_path} due to missing values.")
        continue

    # Extract filename from path
    file_name = os.path.basename(test_audio_path).replace(".mp3", "")

    # Convert to float32 and ensure correct shape
    predicted_vocals = np.asarray(predicted_vocals, dtype=np.float32).T
    predicted_instr = np.asarray(predicted_instr, dtype=np.float32).T

    # Save as WAV with epoch-specific filenames
    sf.write(f"/Users/roydruker/Desktop/Neta/Seperated_files_epochs/{file_name}_vocals_epoch_{epoch+1}.wav", predicted_vocals, 44100, format='WAV')
    sf.write(f"/Users/roydruker/Desktop/Neta/Seperated_files_epochs/{file_name}_instrumental_epoch_{epoch+1}.wav", predicted_instr, 44100, format='WAV')

    print(f"Separated audio saved for epoch {epoch+1}")

print("Fine-tuning completed!")
# Out:
# Epoch 1/10, Loss: 0.004901
# Model saved: /Users/roydruker/Desktop/Neta/Epochs/model_epoch_1.pth
# Processing fma_small/135/135054.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# Separated audio saved for epoch 1
# Epoch 2/10, Loss: 0.004956
# Model saved: /Users/roydruker/Desktop/Neta/Epochs/model_epoch_2.pth
# Processing fma_small/135/135054.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# Separated audio saved for epoch 2
# Epoch 3/10, Loss: 0.005003
# Model saved: /Users/roydruker/Desktop/Neta/Epochs/model_epoch_3.pth
# Processing fma_small/135/135054.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# Separated audio saved for epoch 3
# Epoch 4/10, Loss: 0.004752
# Model saved: /Users/roydruker/Desktop/Neta/Epochs/model_epoch_4.pth
# Processing fma_small/135/135054.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# Separated audio saved for epoch 4
# Epoch 5/10, Loss: 0.004937
# Model saved: /Users/roydruker/Desktop/Neta/Epochs/model_epoch_5.pth
# Processing fma_small/135/135054.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# Separated audio saved for epoch 5
# Epoch 6/10, Loss: 0.006156
# Model saved: /Users/roydruker/Desktop/Neta/Epochs/model_epoch_6.pth
# Processing fma_small/135/135054.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# Separated audio saved for epoch 6
# Epoch 7/10, Loss: 0.006600
# Model saved: /Users/roydruker/Desktop/Neta/Epochs/model_epoch_7.pth
# Processing fma_small/135/135054.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# Separated audio saved for epoch 7
# Epoch 8/10, Loss: 0.006601
# Model saved: /Users/roydruker/Desktop/Neta/Epochs/model_epoch_8.pth
# Processing fma_small/135/135054.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# Separated audio saved for epoch 8
# Epoch 9/10, Loss: 0.009402
# Model saved: /Users/roydruker/Desktop/Neta/Epochs/model_epoch_9.pth
# Processing fma_small/135/135054.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# Separated audio saved for epoch 9
# Epoch 10/10, Loss: 0.004978
# Model saved: /Users/roydruker/Desktop/Neta/Epochs/model_epoch_10.pth
# Processing fma_small/135/135054.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# Separated audio saved for epoch 10
# Fine-tuning completed!

# %%
# Load model checkpoint for epoch 5
checkpoint_path = "Epochs/model_epoch_5.pth"
model.load_state_dict(torch.load(checkpoint_path, map_location=device))
model.eval()

print("Model checkpoint for Epoch 5 loaded!")
# Out:
# Model checkpoint for Epoch 5 loaded!

# %%
import torch
import numpy as np

# Load model checkpoint for epoch 5
checkpoint_path = f"/Users/roydruker/Desktop/Neta/Epochs/model_epoch_3.pth"

model.load_state_dict(torch.load(checkpoint_path))
model.eval()  # Set to evaluation mode
print(f" Model loaded from {checkpoint_path}")

# Process the test audio using the loaded model from epoch 5
test_audio_path = "fma_small/135/135054.mp3"
original_audio, predicted_vocals, predicted_instr = process_audio(test_audio_path, model)

# Ensure correct shape before computing metrics
predicted_sources = np.vstack([predicted_vocals, predicted_instr])  # Stack separated sources

# Compute SDR, SIR, SAR for epoch 5
sdr, sir, sar = compute_metrics(original_audio, predicted_sources)

# ✅ Print results
print(f"Epoch 3 Metrics:")
print(f"SDR: {sdr:.2f}")
print(f"SIR: {sir:.2f}")
print(f"SAR: {sar:.2f}")
# Out:
#  Model loaded from /Users/roydruker/Desktop/Neta/Epochs/model_epoch_3.pth
# Processing fma_small/135/135054.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# /var/folders/h_/q162z7bj3253bmp7vwbsdmmm0000gn/T/ipykernel_50204/3312349815.py:8: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, sir, sar, _ = bss_eval_sources(original, separated)
# Epoch 3 Metrics:
# SDR: 5.64
# SIR: 16.48
# SAR: 6.13

# %%
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# Load audio output from epoch 5
vocal_audio, _ = librosa.load("/Users/roydruker/Desktop/Neta/Seperated_files_epochs/135054_vocals_epoch_3.wav", sr=44100)

# Compute Spectrogram
D = librosa.amplitude_to_db(np.abs(librosa.stft(vocal_audio)), ref=np.max)

# Plot Spectrogram
plt.figure(figsize=(10, 4))
librosa.display.specshow(D, sr=44100, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title("Spectrogram of Isolated Vocals (Epoch 3)")
plt.show()

# %%
# **Plot MSE Loss per Epoch**
plt.figure(figsize=(8, 4))
plt.plot(training_losses_per_epoch, label="Epoch Loss", color="red")
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.title("MSE Loss per Training Epoch")
plt.legend()
plt.show()

# Load the fine-tuned model
model.eval()  # Set to evaluation mode
# Out:
# BagOfModels(
#   (models): ModuleList(
#     (0): HDemucs(
#       (encoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv2d(4, 48, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv2d(48, 96, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv2d(96, 192, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv2d(192, 384, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv2d(384, 768, kernel_size=(8, 1), stride=(4, 1))
#           (norm1): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#         (5): HEncLayer(
#           (conv): Conv1d(768, 1536, kernel_size=(4,), stride=(2,), padding=(1,))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(1,), stride=(1,))
#           (norm2): GroupNorm(4, 3072, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#       )
#       (decoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(1536, 768, kernel_size=(4,), stride=(2,))
#           (norm2): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): GroupNorm(4, 3072, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose2d(768, 384, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose2d(384, 192, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose2d(192, 96, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose2d(96, 48, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (5): HDecLayer(
#           (conv_tr): ConvTranspose2d(48, 16, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#       )
#       (tencoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv1d(2, 48, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv1d(48, 96, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv1d(96, 192, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv1d(192, 384, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv1d(384, 768, kernel_size=(8,), stride=(4,), padding=(2,))
#         )
#       )
#       (tdecoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(768, 384, kernel_size=(8,), stride=(4,))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose1d(384, 192, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose1d(192, 96, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose1d(96, 48, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose1d(48, 8, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#       )
#       (freq_emb): ScaledEmbedding(
#         (embedding): Embedding(512, 48)
#       )
#     )
#     (1-2): 2 x HDemucs(
#       (encoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv2d(2, 48, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv2d(48, 96, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv2d(96, 192, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv2d(192, 384, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv2d(384, 768, kernel_size=(8, 1), stride=(4, 1))
#           (norm1): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#         (5): HEncLayer(
#           (conv): Conv1d(768, 1536, kernel_size=(4,), stride=(2,), padding=(1,))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(1,), stride=(1,))
#           (norm2): GroupNorm(4, 3072, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#       )
#       (decoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(1536, 768, kernel_size=(4,), stride=(2,))
#           (norm2): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): GroupNorm(4, 3072, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose2d(768, 384, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose2d(384, 192, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose2d(192, 96, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose2d(96, 48, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (5): HDecLayer(
#           (conv_tr): ConvTranspose2d(48, 8, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#       )
#       (tencoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv1d(2, 48, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv1d(48, 96, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv1d(96, 192, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv1d(192, 384, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv1d(384, 768, kernel_size=(8,), stride=(4,), padding=(2,))
#         )
#       )
#       (tdecoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(768, 384, kernel_size=(8,), stride=(4,))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose1d(384, 192, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose1d(192, 96, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose1d(96, 48, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose1d(48, 8, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#       )
#       (freq_emb): ScaledEmbedding(
#         (embedding): Embedding(512, 48)
#       )
#     )
#     (3): HDemucs(
#       (encoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv2d(4, 48, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv2d(48, 96, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv2d(96, 192, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv2d(192, 384, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv2d(384, 768, kernel_size=(8, 1), stride=(4, 1))
#           (norm1): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#         (5): HEncLayer(
#           (conv): Conv1d(768, 1536, kernel_size=(4,), stride=(2,), padding=(1,))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(1,), stride=(1,))
#           (norm2): GroupNorm(4, 3072, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#       )
#       (decoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(1536, 768, kernel_size=(4,), stride=(2,))
#           (norm2): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): GroupNorm(4, 3072, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose2d(768, 384, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose2d(384, 192, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose2d(192, 96, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose2d(96, 48, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (5): HDecLayer(
#           (conv_tr): ConvTranspose2d(48, 16, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#       )
#       (tencoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv1d(2, 48, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv1d(48, 96, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv1d(96, 192, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv1d(192, 384, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv1d(384, 768, kernel_size=(8,), stride=(4,), padding=(2,))
#         )
#       )
#       (tdecoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(768, 384, kernel_size=(8,), stride=(4,))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose1d(384, 192, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose1d(192, 96, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose1d(96, 48, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose1d(48, 8, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#       )
#       (freq_emb): ScaledEmbedding(
#         (embedding): Embedding(512, 48)
#       )
#     )
#   )
# )

# %%
#fine tuning with different hyperparams - expirament 1
# Define hyperparameter search space
learning_rates = [1e-3, 1e-4, 1e-5]
batch_sizes = [4, 8, 16]
optimizers = [optim.Adam, optim.SGD, optim.RMSprop]

# Store results
experiment_results = []

# Iterate over all hyperparameter combinations
for lr in learning_rates:
    for batch_size in batch_sizes:
        for opt in optimizers:
            print(f"\n Training with {opt.__name__}, LR={lr}, Batch Size={batch_size}")

            # Update DataLoader with new batch size
            train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

            # Initialize optimizer
            optimizer = opt(model.parameters(), lr=lr)

            # Training settings
            criterion = nn.L1Loss()
            num_epochs = 10  
            training_losses = []

            # Training loop
            for epoch in range(num_epochs):
                model.train()
                total_loss = 0

                for mix, vocals in train_loader:
                    mix, vocals = mix.to(device), vocals.to(device)

                    optimizer.zero_grad()
                    predictions = apply_model(model, mix)[:, 0, :, :].requires_grad_(True)  
                    loss = criterion(predictions, vocals)
                    loss.backward()
                    optimizer.step()

                    total_loss += loss.item()

                avg_loss = total_loss / len(train_loader)
                training_losses.append(avg_loss)  
                print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {avg_loss:.6f}")

            print("Fine-tuning completed!")

            # Save results
            experiment_results.append((opt.__name__, lr, batch_size, min(training_losses)))

# Convert results to DataFrame for analysis
df_experiments = pd.DataFrame(experiment_results, columns=["Optimizer", "Learning Rate", "Batch Size", "Min Loss"])
print("\n Experiment Results:")
print(df_experiments)

# Save results
df_experiments.to_csv("hyperparameter_experiments.csv", index=False)
# Out:
#  Training with Adam, LR=0.001, Batch Size=4
# Epoch 1/10, Loss: 0.006501
# Epoch 2/10, Loss: 0.005507
# Epoch 3/10, Loss: 0.005785
# Epoch 4/10, Loss: 0.006278
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 36
#      33 mix, vocals = mix.to(device), vocals.to(device)
#      35 optimizer.zero_grad()
# ---> 36 predictions = apply_model(model, mix)[:, 0, :, :].requires_grad_(True)
#      37 loss = criterion(predictions, vocals)
#      38 loss.backward()
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/demucs/apply.py:189, in apply_model(model, mix, shifts, split, overlap, transition_power, progress, device, num_workers, segment, pool)
#     186 original_model_device = next(iter(sub_model.parameters())).device
#     187 sub_model.to(device)
# --> 189 out = apply_model(sub_model, mix, **kwargs)
#     190 sub_model.to(original_model_device)
#     191 for k, inst_weight in enumerate(model_weights):
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/demucs/apply.py:216, in apply_model(model, mix, shifts, split, overlap, transition_power, progress, device, num_workers, segment, pool)
#     214     offset = random.randint(0, max_shift)
#     215     shifted = TensorChunk(padded_mix, offset, length + max_shift - offset)
# --> 216     shifted_out = apply_model(model, shifted, **kwargs)
#     217     out += shifted_out[..., max_shift - offset:]
#     218 out /= shifts
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/demucs/apply.py:250, in apply_model(model, mix, shifts, split, overlap, transition_power, progress, device, num_workers, segment, pool)
#     248     futures = tqdm.tqdm(futures, unit_scale=scale, ncols=120, unit='seconds')
#     249 for future, offset in futures:
# --> 250     chunk_out = future.result()
#     251     chunk_length = chunk_out.shape[-1]
#     252     out[..., offset:offset + segment_length] += (
#     253         weight[:chunk_length] * chunk_out).to(mix.device)
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/demucs/utils.py:129, in DummyPoolExecutor.DummyResult.result(self)
#     128 def result(self):
# --> 129     return self.func(*self.args, **self.kwargs)
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/demucs/apply.py:271, in apply_model(model, mix, shifts, split, overlap, transition_power, progress, device, num_workers, segment, pool)
#     269 padded_mix = mix.padded(valid_length).to(device)
#     270 with th.no_grad():
# --> 271     out = model(padded_mix)
#     272 assert isinstance(out, th.Tensor)
#     273 return center_trim(out, length)
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/demucs/hdemucs.py:732, in HDemucs.forward(self, mix)
#     728     else:
#     729         # tenc contains just the first conv., so that now time and freq.
#     730         # branches have the same shape and can be merged.
#     731         inject = xt
# --> 732 x = encode(x, inject)
#     733 if idx == 0 and self.freq_emb is not None:
#     734     # add frequency embedding to allow for non equivariant convolutions
#     735     # over the frequency axis.
#     736     frs = torch.arange(x.shape[-2], device=x.device)
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/demucs/hdemucs.py:149, in HEncLayer.forward(self, x, inject)
#     147     B, C, Fr, T = y.shape
#     148     y = y.permute(0, 2, 1, 3).reshape(-1, C, T)
# --> 149 y = self.dconv(y)
#     150 if self.freq:
#     151     y = y.view(B, Fr, C, T).permute(0, 2, 1, 3)
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/demucs/demucs.py:153, in DConv.forward(self, x)
#     151 def forward(self, x):
#     152     for layer in self.layers:
# --> 153         x = x + layer(x)
#     154     return x
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/demucs/demucs.py:48, in BLSTM.forward(self, x)
#      44     x = frames.permute(0, 2, 1, 3).reshape(-1, C, width)
#      46 x = x.permute(2, 0, 1)
# ---> 48 x = self.lstm(x)[0]
#      49 x = self.linear(x)
#      50 x = x.permute(1, 2, 0)
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.venvs/py3118/lib/python3.12/site-packages/torch/nn/modules/rnn.py:1124, in LSTM.forward(self, input, hx)
#    1121         hx = self.permute_hidden(hx, sorted_indices)
#    1123 if batch_sizes is None:
# -> 1124     result = _VF.lstm(
#    1125         input,
#    1126         hx,
#    1127         self._flat_weights,  # type: ignore[arg-type]
#    1128         self.bias,
#    1129         self.num_layers,
#    1130         self.dropout,
#    1131         self.training,
#    1132         self.bidirectional,
#    1133         self.batch_first,
#    1134     )
#    1135 else:
#    1136     result = _VF.lstm(
#    1137         input,
#    1138         batch_sizes,
#    (...)
#    1145         self.bidirectional,
#    1146     )
#
# KeyboardInterrupt:

# %%
# Convert results to DataFrame for analysis
df_experiments = pd.DataFrame(experiment_results, columns=["Optimizer", "Learning Rate", "Batch Size", "Min Loss"])
print("\n Experiment Results:")
print(df_experiments)

# Save results
df_experiments.to_csv("hyperparameter_experiments.csv", index=False)
# Out:
#  Experiment Results:
#    Optimizer  Learning Rate  Batch Size  Min Loss
# 0       Adam        0.00100           4  0.010699
# 1        SGD        0.00100           4  0.009661
# 2    RMSprop        0.00100           4  0.010458
# 3       Adam        0.00100           8  0.008801
# 4        SGD        0.00100           8  0.010879
# 5    RMSprop        0.00100           8  0.007725
# 6       Adam        0.00100          16  0.011274
# 7        SGD        0.00100          16  0.011287
# 8    RMSprop        0.00100          16  0.011243
# 9       Adam        0.00010           4  0.010346
# 10       SGD        0.00010           4  0.009717
# 11   RMSprop        0.00010           4  0.010714
# 12      Adam        0.00010           8  0.008575
# 13       SGD        0.00010           8  0.008365
# 14   RMSprop        0.00010           8  0.009966
# 15      Adam        0.00010          16  0.011211
# 16       SGD        0.00010          16  0.011088
# 17   RMSprop        0.00010          16  0.011350
# 18      Adam        0.00001           4  0.010448
# 19       SGD        0.00001           4  0.009974
# 20   RMSprop        0.00001           4  0.010797
# 21      Adam        0.00001           8  0.008089
# 22       SGD        0.00001           8  0.010938
# 23   RMSprop        0.00001           8  0.009879
# 24      Adam        0.00001          16  0.011351
# 25       SGD        0.00001          16  0.011177
# 26   RMSprop        0.00001          16  0.011241

# %%
model.eval()
# Out:
# BagOfModels(
#   (models): ModuleList(
#     (0): HDemucs(
#       (encoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv2d(4, 48, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv2d(48, 96, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv2d(96, 192, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv2d(192, 384, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv2d(384, 768, kernel_size=(8, 1), stride=(4, 1))
#           (norm1): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#         (5): HEncLayer(
#           (conv): Conv1d(768, 1536, kernel_size=(4,), stride=(2,), padding=(1,))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(1,), stride=(1,))
#           (norm2): GroupNorm(4, 3072, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#       )
#       (decoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(1536, 768, kernel_size=(4,), stride=(2,))
#           (norm2): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): GroupNorm(4, 3072, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose2d(768, 384, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose2d(384, 192, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose2d(192, 96, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose2d(96, 48, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (5): HDecLayer(
#           (conv_tr): ConvTranspose2d(48, 16, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#       )
#       (tencoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv1d(2, 48, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv1d(48, 96, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv1d(96, 192, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv1d(192, 384, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv1d(384, 768, kernel_size=(8,), stride=(4,), padding=(2,))
#         )
#       )
#       (tdecoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(768, 384, kernel_size=(8,), stride=(4,))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose1d(384, 192, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose1d(192, 96, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose1d(96, 48, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose1d(48, 8, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#       )
#       (freq_emb): ScaledEmbedding(
#         (embedding): Embedding(512, 48)
#       )
#     )
#     (1-2): 2 x HDemucs(
#       (encoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv2d(2, 48, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv2d(48, 96, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv2d(96, 192, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv2d(192, 384, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv2d(384, 768, kernel_size=(8, 1), stride=(4, 1))
#           (norm1): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#         (5): HEncLayer(
#           (conv): Conv1d(768, 1536, kernel_size=(4,), stride=(2,), padding=(1,))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(1,), stride=(1,))
#           (norm2): GroupNorm(4, 3072, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#       )
#       (decoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(1536, 768, kernel_size=(4,), stride=(2,))
#           (norm2): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): GroupNorm(4, 3072, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose2d(768, 384, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose2d(384, 192, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose2d(192, 96, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose2d(96, 48, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (5): HDecLayer(
#           (conv_tr): ConvTranspose2d(48, 8, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#       )
#       (tencoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv1d(2, 48, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv1d(48, 96, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv1d(96, 192, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv1d(192, 384, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv1d(384, 768, kernel_size=(8,), stride=(4,), padding=(2,))
#         )
#       )
#       (tdecoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(768, 384, kernel_size=(8,), stride=(4,))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose1d(384, 192, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose1d(192, 96, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose1d(96, 48, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose1d(48, 8, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#       )
#       (freq_emb): ScaledEmbedding(
#         (embedding): Embedding(512, 48)
#       )
#     )
#     (3): HDemucs(
#       (encoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv2d(4, 48, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv2d(48, 96, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv2d(96, 192, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv2d(192, 384, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv2d(384, 768, kernel_size=(8, 1), stride=(4, 1))
#           (norm1): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#         (5): HEncLayer(
#           (conv): Conv1d(768, 1536, kernel_size=(4,), stride=(2,), padding=(1,))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(1,), stride=(1,))
#           (norm2): GroupNorm(4, 3072, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#       )
#       (decoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(1536, 768, kernel_size=(4,), stride=(2,))
#           (norm2): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): GroupNorm(4, 3072, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose2d(768, 384, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose2d(384, 192, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose2d(192, 96, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose2d(96, 48, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (5): HDecLayer(
#           (conv_tr): ConvTranspose2d(48, 16, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#       )
#       (tencoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv1d(2, 48, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv1d(48, 96, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv1d(96, 192, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv1d(192, 384, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv1d(384, 768, kernel_size=(8,), stride=(4,), padding=(2,))
#         )
#       )
#       (tdecoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(768, 384, kernel_size=(8,), stride=(4,))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose1d(384, 192, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose1d(192, 96, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose1d(96, 48, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose1d(48, 8, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#       )
#       (freq_emb): ScaledEmbedding(
#         (embedding): Embedding(512, 48)
#       )
#     )
#   )
# )

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# ✅ Ensure DataFrame contains the correct columns
df_experiments = pd.DataFrame(experiment_results, columns=["Optimizer", "Learning Rate", "Batch Size", "Min Loss"])

# ✅ Bar Chart: Minimum Loss per Optimizer & Learning Rate
plt.figure(figsize=(12, 5))
sns.barplot(x="Learning Rate", y="Min Loss", hue="Optimizer", data=df_experiments, palette="viridis")
plt.title("Best Training Loss per Optimizer and Learning Rate")
plt.xlabel("Learning Rate")
plt.ylabel("Minimum Loss Achieved")
plt.legend(title="Optimizer")
plt.show()

# ✅ Line Graph: Loss Trend Across Batch Sizes
plt.figure(figsize=(12, 5))
sns.lineplot(x="Batch Size", y="Min Loss", hue="Optimizer", style="Optimizer", data=df_experiments, markers=True, dashes=False)
plt.title("Loss Trend Across Different Batch Sizes")
plt.xlabel("Batch Size")
plt.ylabel("Minimum Loss Achieved")
plt.legend(title="Optimizer")
plt.show()

# ✅ Save results to CSV
df_experiments.to_csv("hyperparameter_experiments.csv", index=False)
print("\n✅ Experiment results saved to hyperparameter_experiments.csv")
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ✅ Experiment results saved to hyperparameter_experiments.csv

# %%
# Load the fine-tuned model
model.eval()  # Set to evaluation mode
# Out:
# BagOfModels(
#   (models): ModuleList(
#     (0): HDemucs(
#       (encoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv2d(4, 48, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv2d(48, 96, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv2d(96, 192, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv2d(192, 384, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv2d(384, 768, kernel_size=(8, 1), stride=(4, 1))
#           (norm1): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#         (5): HEncLayer(
#           (conv): Conv1d(768, 1536, kernel_size=(4,), stride=(2,), padding=(1,))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(1,), stride=(1,))
#           (norm2): GroupNorm(4, 3072, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#       )
#       (decoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(1536, 768, kernel_size=(4,), stride=(2,))
#           (norm2): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): GroupNorm(4, 3072, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose2d(768, 384, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose2d(384, 192, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose2d(192, 96, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose2d(96, 48, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (5): HDecLayer(
#           (conv_tr): ConvTranspose2d(48, 16, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#       )
#       (tencoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv1d(2, 48, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv1d(48, 96, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv1d(96, 192, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv1d(192, 384, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv1d(384, 768, kernel_size=(8,), stride=(4,), padding=(2,))
#         )
#       )
#       (tdecoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(768, 384, kernel_size=(8,), stride=(4,))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose1d(384, 192, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose1d(192, 96, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose1d(96, 48, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose1d(48, 8, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#       )
#       (freq_emb): ScaledEmbedding(
#         (embedding): Embedding(512, 48)
#       )
#     )
#     (1-2): 2 x HDemucs(
#       (encoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv2d(2, 48, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv2d(48, 96, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv2d(96, 192, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv2d(192, 384, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv2d(384, 768, kernel_size=(8, 1), stride=(4, 1))
#           (norm1): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#         (5): HEncLayer(
#           (conv): Conv1d(768, 1536, kernel_size=(4,), stride=(2,), padding=(1,))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(1,), stride=(1,))
#           (norm2): GroupNorm(4, 3072, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#       )
#       (decoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(1536, 768, kernel_size=(4,), stride=(2,))
#           (norm2): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): GroupNorm(4, 3072, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose2d(768, 384, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose2d(384, 192, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose2d(192, 96, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose2d(96, 48, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (5): HDecLayer(
#           (conv_tr): ConvTranspose2d(48, 8, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#       )
#       (tencoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv1d(2, 48, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv1d(48, 96, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv1d(96, 192, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv1d(192, 384, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv1d(384, 768, kernel_size=(8,), stride=(4,), padding=(2,))
#         )
#       )
#       (tdecoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(768, 384, kernel_size=(8,), stride=(4,))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose1d(384, 192, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose1d(192, 96, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose1d(96, 48, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose1d(48, 8, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#       )
#       (freq_emb): ScaledEmbedding(
#         (embedding): Embedding(512, 48)
#       )
#     )
#     (3): HDemucs(
#       (encoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv2d(4, 48, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv2d(48, 96, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv2d(96, 192, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv2d(192, 384, kernel_size=(8, 1), stride=(4, 1), padding=(2, 0))
#           (norm1): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv2d(384, 768, kernel_size=(8, 1), stride=(4, 1))
#           (norm1): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (norm2): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(768, 192, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(192, 192, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=384, out_features=192, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(192, 1536, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 1536, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#         (5): HEncLayer(
#           (conv): Conv1d(768, 1536, kernel_size=(4,), stride=(2,), padding=(1,))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(1,), stride=(1,))
#           (norm2): GroupNorm(4, 3072, eps=1e-05, affine=True)
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): BLSTM(
#                   (lstm): LSTM(384, 384, num_layers=2, bidirectional=True)
#                   (linear): Linear(in_features=768, out_features=384, bias=True)
#                 )
#                 (4): LocalState(
#                   (content): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (key): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                   (query_decay): Conv1d(384, 16, kernel_size=(1,), stride=(1,))
#                   (proj): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#                 )
#                 (5): Conv1d(384, 3072, kernel_size=(1,), stride=(1,))
#                 (6): GroupNorm(1, 3072, eps=1e-05, affine=True)
#                 (7): GLU(dim=1)
#                 (8): LayerScale()
#               )
#             )
#           )
#         )
#       )
#       (decoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(1536, 768, kernel_size=(4,), stride=(2,))
#           (norm2): GroupNorm(4, 768, eps=1e-05, affine=True)
#           (rewrite): Conv1d(1536, 3072, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): GroupNorm(4, 3072, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose2d(768, 384, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#           (rewrite): Conv2d(768, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): GroupNorm(4, 1536, eps=1e-05, affine=True)
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose2d(384, 192, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(384, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose2d(192, 96, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose2d(96, 48, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(96, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#         (5): HDecLayer(
#           (conv_tr): ConvTranspose2d(48, 16, kernel_size=(8, 1), stride=(4, 1))
#           (norm2): Identity()
#           (rewrite): Conv2d(48, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm1): Identity()
#         )
#       )
#       (tencoder): ModuleList(
#         (0): HEncLayer(
#           (conv): Conv1d(2, 48, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(48, 12, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 12, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(12, 96, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (1): HEncLayer(
#           (conv): Conv1d(48, 96, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(96, 24, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 24, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(24, 192, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 192, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (2): HEncLayer(
#           (conv): Conv1d(96, 192, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(192, 48, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 48, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(48, 384, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 384, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (3): HEncLayer(
#           (conv): Conv1d(192, 384, kernel_size=(8,), stride=(4,), padding=(2,))
#           (norm1): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(1,), stride=(1,))
#           (norm2): Identity()
#           (dconv): DConv(
#             (layers): ModuleList(
#               (0): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#               (1): Sequential(
#                 (0): Conv1d(384, 96, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,))
#                 (1): GroupNorm(1, 96, eps=1e-05, affine=True)
#                 (2): GELU(approximate='none')
#                 (3): Conv1d(96, 768, kernel_size=(1,), stride=(1,))
#                 (4): GroupNorm(1, 768, eps=1e-05, affine=True)
#                 (5): GLU(dim=1)
#                 (6): LayerScale()
#               )
#             )
#           )
#         )
#         (4): HEncLayer(
#           (conv): Conv1d(384, 768, kernel_size=(8,), stride=(4,), padding=(2,))
#         )
#       )
#       (tdecoder): ModuleList(
#         (0): HDecLayer(
#           (conv_tr): ConvTranspose1d(768, 384, kernel_size=(8,), stride=(4,))
#           (norm2): GroupNorm(4, 384, eps=1e-05, affine=True)
#         )
#         (1): HDecLayer(
#           (conv_tr): ConvTranspose1d(384, 192, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(384, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (2): HDecLayer(
#           (conv_tr): ConvTranspose1d(192, 96, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(192, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (3): HDecLayer(
#           (conv_tr): ConvTranspose1d(96, 48, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(96, 192, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#         (4): HDecLayer(
#           (conv_tr): ConvTranspose1d(48, 8, kernel_size=(8,), stride=(4,))
#           (norm2): Identity()
#           (rewrite): Conv1d(48, 96, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm1): Identity()
#         )
#       )
#       (freq_emb): ScaledEmbedding(
#         (embedding): Embedding(512, 48)
#       )
#     )
#   )
# )

# %%
# Get all MP3 files from subdirectories
all_mp3_files = glob.glob(os.path.join("fma_small", "*/*.mp3"))  # Recursively fetch files

# Pick test files that were NOT used in fine-tuning
test_files = [f for f in all_mp3_files if f not in selected_files][:10]  # Select 10 unseen files

print(f"Selected {len(test_files)} test files.")
# Out:
# Selected 10 test files.

# %%
def compute_metrics(original, separated):
    """Computes SDR, SIR, and SAR for separated vocals."""
    try:
        min_length = min(original.shape[1], separated.shape[1])
        original = original[:, :min_length]
        separated = separated[:2, :min_length]  # Ensure only two sources

        sdr, sir, sar, _ = bss_eval_sources(original, separated)
        return np.mean(sdr), np.mean(sir), np.mean(sar)
    except Exception as e:
        print(f"Error computing metrics: {e}")
        return None, None, None

# %%
evaluation_results = []

for file in test_files:
    print(f"\n Evaluating: {file}")

    # Process file through the fine-tuned model
    original_audio, predicted_vocals, predicted_instr = process_audio(file, model) 

    if original_audio is not None and predicted_vocals is not None:
        sdr, sir, sar = compute_metrics(original_audio, np.vstack([predicted_vocals, predicted_instr]))

        evaluation_results.append((file, sdr, sir, sar))
        print(f"{file}: SDR={sdr:.2f}, SIR={sir:.2f}, SAR={sar:.2f}")

# Convert results to DataFrame
df_results = pd.DataFrame(evaluation_results, columns=["Track", "SDR", "SIR", "SAR"])
print("\n Evaluation Results:")
print(df_results)

# Save results to CSV
df_results.to_csv("fine_tuning_evaluation.csv", index=False)
# Out:
#  Evaluating: fma_small/135/135054.mp3
# Processing fma_small/135/135054.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# /var/folders/h_/q162z7bj3253bmp7vwbsdmmm0000gn/T/ipykernel_42964/3312349815.py:8: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, sir, sar, _ = bss_eval_sources(original, separated)
# fma_small/135/135054.mp3: SDR=5.86, SIR=16.65, SAR=6.34
#
#  Evaluating: fma_small/135/135336.mp3
# Processing fma_small/135/135336.mp3
# Loaded Audio: Shape = (2, 1321967), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1321967)
# fma_small/135/135336.mp3: SDR=0.85, SIR=14.50, SAR=1.24
#
#  Evaluating: fma_small/135/135337.mp3
# Processing fma_small/135/135337.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# fma_small/135/135337.mp3: SDR=3.10, SIR=13.07, SAR=3.86
#
#  Evaluating: fma_small/135/135043.mp3
# Processing fma_small/135/135043.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# fma_small/135/135043.mp3: SDR=-4.77, SIR=12.68, SAR=-4.42
#
#  Evaluating: fma_small/135/135091.mp3
# Processing fma_small/135/135091.mp3
# Loaded Audio: Shape = (2, 1321967), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1321967)
# fma_small/135/135091.mp3: SDR=-2.95, SIR=15.91, SAR=-2.79
#
#  Evaluating: fma_small/135/135092.mp3
# Processing fma_small/135/135092.mp3
# Loaded Audio: Shape = (2, 1321967), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1321967)
# fma_small/135/135092.mp3: SDR=-11.21, SIR=11.06, SAR=-10.72
#
#  Evaluating: fma_small/135/135044.mp3
# Processing fma_small/135/135044.mp3
# Loaded Audio: Shape = (2, 1321967), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1321967)
# fma_small/135/135044.mp3: SDR=-15.30, SIR=-0.08, SAR=-11.49
#
#  Evaluating: fma_small/135/135989.mp3
# Processing fma_small/135/135989.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# fma_small/135/135989.mp3: SDR=3.65, SIR=11.80, SAR=4.72
#
#  Evaluating: fma_small/135/135221.mp3
# Processing fma_small/135/135221.mp3
# Loaded Audio: Shape = (2, 1321967), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1321967)
# fma_small/135/135221.mp3: SDR=3.54, SIR=22.32, SAR=3.62
#
#  Evaluating: fma_small/135/135369.mp3
# Processing fma_small/135/135369.mp3
# Loaded Audio: Shape = (2, 1321967), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1321967)
# fma_small/135/135369.mp3: SDR=3.44, SIR=14.39, SAR=3.97
#
#  Evaluation Results:
#                       Track        SDR        SIR        SAR
# 0  fma_small/135/135054.mp3   5.859403  16.648746   6.344234
# 1  fma_small/135/135336.mp3   0.850758  14.502261   1.239691
# 2  fma_small/135/135337.mp3   3.100240  13.067614   3.857479
# 3  fma_small/135/135043.mp3  -4.766630  12.684315  -4.424670
# 4  fma_small/135/135091.mp3  -2.954194  15.913772  -2.787329
# 5  fma_small/135/135092.mp3 -11.211323  11.064407 -10.716163
# 6  fma_small/135/135044.mp3 -15.304207  -0.077206 -11.488639
# 7  fma_small/135/135989.mp3   3.654967  11.801889   4.715288
# 8  fma_small/135/135221.mp3   3.535225  22.323430   3.618387
# 9  fma_small/135/135369.mp3   3.444957  14.392305   3.966958

# %%
# Load the original pre-trained model
original_model = pretrained.get_model(name="mdx_extra").to(device)
original_model.eval()

def compare_models(test_files):
    results = []

    for file in test_files:
        print(f"\n🔍 Evaluating {file} on both models...")

        # Process file through both models
        _, fine_tuned_vocals, fine_tuned_instr = process_audio(file, model)  # Fine-tuned model
        _, original_vocals, original_instr = process_audio(file, original_model)  # Pretrained model

        if fine_tuned_vocals is not None and original_vocals is not None:
            # Ensure correct dimensions for both vocals and instrumental
            fine_tuned_vocals = np.atleast_2d(fine_tuned_vocals)
            fine_tuned_instr = np.atleast_2d(fine_tuned_instr)
            original_vocals = np.atleast_2d(original_vocals)
            original_instr = np.atleast_2d(original_instr)

            # Stack to create full sources
            fine_tuned_sources = np.vstack([fine_tuned_vocals, fine_tuned_instr])
            original_sources = np.vstack([original_vocals, original_instr])

            # Compute SDR, handling cases where fewer values are returned
            fine_tuned_metrics = bss_eval_sources(original_sources, fine_tuned_sources)
            original_metrics = bss_eval_sources(original_sources, original_sources)  # Reference SDR

            # Extract SDR values (support cases where only SDR is returned)
            fine_tuned_sdr = fine_tuned_metrics[0] if isinstance(fine_tuned_metrics, tuple) else fine_tuned_metrics
            original_sdr = original_metrics[0] if isinstance(original_metrics, tuple) else original_metrics

            # Store results
            results.append((file, np.mean(original_sdr), np.mean(fine_tuned_sdr)))
            print(f"{file}: Pretrained SDR={np.mean(original_sdr):.2f}, Fine-Tuned SDR={np.mean(fine_tuned_sdr):.2f}")

    return results

# Run comparison
comparison_results = compare_models(test_files)

# Convert to DataFrame and display
df_comparison = pd.DataFrame(comparison_results, columns=["Track", "Pretrained SDR", "Fine-Tuned SDR"])
print("\n Model Comparison Results:")
print(df_comparison)

# Save results to CSV
df_comparison.to_csv("model_comparison.csv", index=False)
# Out:
# 🔍 Evaluating fma_small/135/135054.mp3 on both models...
# Processing fma_small/135/135054.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# Processing fma_small/135/135054.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# /var/folders/h_/q162z7bj3253bmp7vwbsdmmm0000gn/T/ipykernel_42964/3737079321.py:27: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   fine_tuned_metrics = bss_eval_sources(original_sources, fine_tuned_sources)
# /var/folders/h_/q162z7bj3253bmp7vwbsdmmm0000gn/T/ipykernel_42964/3737079321.py:28: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   original_metrics = bss_eval_sources(original_sources, original_sources)  # Reference SDR
# ✅ fma_small/135/135054.mp3: Pretrained SDR=245.70, Fine-Tuned SDR=19.75
#
# 🔍 Evaluating fma_small/135/135336.mp3 on both models...
# Processing fma_small/135/135336.mp3
# Loaded Audio: Shape = (2, 1321967), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1321967)
# Processing fma_small/135/135336.mp3
# Loaded Audio: Shape = (2, 1321967), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1321967)
# ✅ fma_small/135/135336.mp3: Pretrained SDR=248.90, Fine-Tuned SDR=15.41
#
# 🔍 Evaluating fma_small/135/135337.mp3 on both models...
# Processing fma_small/135/135337.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# Processing fma_small/135/135337.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# ✅ fma_small/135/135337.mp3: Pretrained SDR=256.39, Fine-Tuned SDR=34.09
#
# 🔍 Evaluating fma_small/135/135043.mp3 on both models...
# Processing fma_small/135/135043.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# Processing fma_small/135/135043.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# ✅ fma_small/135/135043.mp3: Pretrained SDR=265.26, Fine-Tuned SDR=26.30
#
# 🔍 Evaluating fma_small/135/135091.mp3 on both models...
# Processing fma_small/135/135091.mp3
# Loaded Audio: Shape = (2, 1321967), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1321967)
# Processing fma_small/135/135091.mp3
# Loaded Audio: Shape = (2, 1321967), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1321967)
# ✅ fma_small/135/135091.mp3: Pretrained SDR=266.79, Fine-Tuned SDR=29.56
#
# 🔍 Evaluating fma_small/135/135092.mp3 on both models...
# Processing fma_small/135/135092.mp3
# Loaded Audio: Shape = (2, 1321967), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1321967)
# Processing fma_small/135/135092.mp3
# Loaded Audio: Shape = (2, 1321967), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1321967)
# ✅ fma_small/135/135092.mp3: Pretrained SDR=254.67, Fine-Tuned SDR=27.27
#
# 🔍 Evaluating fma_small/135/135044.mp3 on both models...
# Processing fma_small/135/135044.mp3
# Loaded Audio: Shape = (2, 1321967), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1321967)
# Processing fma_small/135/135044.mp3
# Loaded Audio: Shape = (2, 1321967), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1321967)
# ✅ fma_small/135/135044.mp3: Pretrained SDR=255.27, Fine-Tuned SDR=28.03
#
# 🔍 Evaluating fma_small/135/135989.mp3 on both models...
# Processing fma_small/135/135989.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# Processing fma_small/135/135989.mp3
# Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1323119)
# ✅ fma_small/135/135989.mp3: Pretrained SDR=244.28, Fine-Tuned SDR=26.14
#
# 🔍 Evaluating fma_small/135/135221.mp3 on both models...
# Processing fma_small/135/135221.mp3
# Loaded Audio: Shape = (2, 1321967), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1321967)
# Processing fma_small/135/135221.mp3
# Loaded Audio: Shape = (2, 1321967), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1321967)
# ✅ fma_small/135/135221.mp3: Pretrained SDR=282.16, Fine-Tuned SDR=20.67
#
# 🔍 Evaluating fma_small/135/135369.mp3 on both models...
# Processing fma_small/135/135369.mp3
# Loaded Audio: Shape = (2, 1321967), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1321967)
# Processing fma_small/135/135369.mp3
# Loaded Audio: Shape = (2, 1321967), Sample Rate = 44100
#  Model Output Shape: (1, 4, 2, 1321967)
# ✅ fma_small/135/135369.mp3: Pretrained SDR=256.45, Fine-Tuned SDR=34.65
#
#  Model Comparison Results:
#                       Track  Pretrained SDR  Fine-Tuned SDR
# 0  fma_small/135/135054.mp3      245.698194       19.749667
# 1  fma_small/135/135336.mp3      248.900574       15.411106
# 2  fma_small/135/135337.mp3      256.388396       34.085909
# 3  fma_small/135/135043.mp3      265.258689       26.299878
# 4  fma_small/135/135091.mp3      266.793944       29.556037
# 5  fma_small/135/135092.mp3      254.672314       27.267076
# 6  fma_small/135/135044.mp3      255.265510       28.025469
# 7  fma_small/135/135989.mp3      244.275255       26.140613
# 8  fma_small/135/135221.mp3      282.156151       20.668311
# 9  fma_small/135/135369.mp3      256.451015       34.654079

# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

def plot_spectrogram(audio, sr, title):
    """Plots the spectrogram of an audio signal."""
    plt.figure(figsize=(10, 4))
    S = librosa.amplitude_to_db(np.abs(librosa.stft(audio)), ref=np.max)
    librosa.display.specshow(S, sr=sr, x_axis="time", y_axis="log")
    plt.colorbar(format="%+2.0f dB")
    plt.title(title)
    plt.show()

# %%
# Load test file for visualization
test_file = test_files[0]  # Use the first file from the test set
y, sr = librosa.load(test_file, sr=AUDIO_SAMPLE_RATE, mono=True)
plot_spectrogram(y, sr, "Original Audio")

# Process file through the fine-tuned model
original, vocals, instrumental = process_audio(test_file, input_model=model)  # Uses updated process_audio function

# Ensure correct shape before plotting
if vocals is not None and instrumental is not None:
    plot_spectrogram(vocals[0], sr, "Isolated Vocals")  # Take channel 0 if stereo
    plot_spectrogram(instrumental[0], sr, "Isolated Instrumental")  # Take channel 0 if stereo
else:
    print(f"Error processing {test_file}, skipping visualization.")
# Out:
# 🎵 Processing fma_small/135/135054.mp3
# ✅ Loaded Audio: Shape = (2, 1323119), Sample Rate = 44100
# ✅ Model Output Shape: (1, 4, 2, 1323119)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
import matplotlib.pyplot as plt

# Define Dataset Split (Train/Test)
train_size = int(0.8 * len(train_dataset))  # 80% for training
test_size = len(train_dataset) - train_size  # 20% for testing
train_subset, test_subset = random_split(train_dataset, [train_size, test_size])

# Create Train and Test DataLoaders
train_loader = DataLoader(train_subset, batch_size=8, shuffle=True)
test_loader = DataLoader(test_subset, batch_size=8, shuffle=False)  # No shuffling for test data

# Define Model, Loss Function, Optimizer
criterion = nn.L1Loss()
optimizer = optim.Adam(model.parameters(), lr=1e-5, betas=(0.9, 0.999))

# Initialize Lists to Store Losses
num_epochs = 10  
training_losses_per_epoch = []  # Track training loss per epoch
test_losses_per_epoch = []  # Track test loss per epoch

# Training and Evaluation Loop
for epoch in range(num_epochs):
    model.train()
    total_train_loss = 0

    # Training Loop
    for mix, vocals in train_loader:
        mix, vocals = mix.to(device), vocals.to(device)

        optimizer.zero_grad()
        predictions = apply_model(model, mix)[:, 0, :, :].requires_grad_(True)  
        loss = criterion(predictions, vocals)
        loss.backward()
        optimizer.step()

        total_train_loss += loss.item()

    # Compute average training loss for this epoch
    avg_train_loss = total_train_loss / len(train_loader)
    training_losses_per_epoch.append(avg_train_loss)

    # Compute Test Loss for This Epoch
    model.eval()
    total_test_loss = 0

    with torch.no_grad():  # Disable gradient computation
        for mix, vocals in test_loader:
            mix, vocals = mix.to(device), vocals.to(device)
            predictions = apply_model(model, mix)[:, 0, :, :]
            loss = criterion(predictions, vocals)
            total_test_loss += loss.item()

    avg_test_loss = total_test_loss / len(test_loader)
    test_losses_per_epoch.append(avg_test_loss)

    print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {avg_train_loss:.6f}, Test Loss: {avg_test_loss:.6f}")

print("Training and Evaluation Completed!")

# Plot Training vs. Test Loss
plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs + 1), training_losses_per_epoch, label="Train Loss", marker='o')
plt.plot(range(1, num_epochs + 1), test_losses_per_epoch, label="Test Loss", marker='s', linestyle='dashed')

plt.xlabel("Epochs")
plt.ylabel("L1 Loss")
plt.title("Training vs. Test Loss Convergence")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/10, Train Loss: 0.006607, Test Loss: 0.006174
# Epoch 2/10, Train Loss: 0.006623, Test Loss: 0.005996
# Epoch 3/10, Train Loss: 0.006287, Test Loss: 0.005814
# Epoch 4/10, Train Loss: 0.006436, Test Loss: 0.005600
# Epoch 5/10, Train Loss: 0.006559, Test Loss: 0.006157
# Epoch 6/10, Train Loss: 0.006189, Test Loss: 0.006012
# Epoch 7/10, Train Loss: 0.006316, Test Loss: 0.005496
# Epoch 8/10, Train Loss: 0.006376, Test Loss: 0.005609
# Epoch 9/10, Train Loss: 0.006439, Test Loss: 0.005835
# Epoch 10/10, Train Loss: 0.006297, Test Loss: 0.005763
# Training and Evaluation Completed!
